# %% [markdown]
# **Partie II**
#
# In this section, we focus on two other important aspects of deep learning: speeding up learning with GPU cards and the ability to use pretrained networks.
#
# To illustrate the first aspect, we will use the GPUs available under Google Colab. To do this, before starting to read the notebook, go to **Modifier**/**Modifier les param du notebook** and select a GPU.
#
# For the second aspect, we will work on a binary classification problem using a small dataset ("hymenoptera_data"). We will see the benefits of using a network that has already been trained on a larger dataset and a more general classification task.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, models, transforms

# %%
# Check GPU availability
if torch.cuda.is_available():
  device = torch.device("cuda:0") # 0 is the index of the GPU
  print("You are on GPU !")
else:
  print('Change the runtime type to GPU')
# Out:
# You are on GPU !

# %% [markdown]
# ## **A.** Load and viz the Hymenoptera dataset:

# %%
# download the dataset
! wget https://download.pytorch.org/tutorial/hymenoptera_data.zip
! unzip -qq hymenoptera_data.zip
# Out:
# --2023-11-09 09:53:29--  https://download.pytorch.org/tutorial/hymenoptera_data.zip
# Resolving download.pytorch.org (download.pytorch.org)... 13.224.250.5, 13.224.250.7, 13.224.250.24, ...
# Connecting to download.pytorch.org (download.pytorch.org)|13.224.250.5|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47286322 (45M) [application/zip]
# Saving to: ‘hymenoptera_data.zip’
#
# hymenoptera_data.zi 100%[===================>]  45.10M   180MB/s    in 0.3s
#
# 2023-11-09 09:53:30 (180 MB/s) - ‘hymenoptera_data.zip’ saved [47286322/47286322]

# %%
dir_data = 'hymenoptera_data'
print(os.listdir(dir_data))
# Out:
# ['train', 'val']

# %% [markdown]
# The dataset is in a standard format, and we can manipulate it with a ready-to-use dataset object of the datasets.ImageFolder class:

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        #transforms.RandomVerticalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

image_datasets = {x: datasets.ImageFolder(os.path.join(dir_data, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=0)
              for x in ['train', 'val']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}

print('Dataset sizs:' )
print(dataset_sizes)
# Out:
# Dataset sizs:
# {'train': 244, 'val': 153}

# %% [markdown]
# Since the provided dataset is very small, we need to maximize its utility. We will produce new images through additional transformations that preserve the nature of the object (data augmentation). \\
# In the code, transforms.*RandomResizedCrop()*, *transforms.RandomHorizontalFlip()* and *transforms.RandomVerticalFlip()* apply horizontal or vertical axis symmetry with a probability of 1/2. Note that these transformations might not be suitable for other datasets like MNIST since the mirror image of a digit is generally not another digit. Therefore, transformations often need to be adapted to the nature of the dataset. \\
# Some images are presented below.

# %%
def imshow(inp, ax=None, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    if ax is None:
      plt.imshow(inp)
      plt.title(title)
    else:
      ax.imshow(inp)
      ax.set_title(title)

# %%
def plot_batch(images, labels, class_names):
    num_images = len(images)
    fig, axs = plt.subplots(1, num_images, figsize=(15, 5))

    for i in range(num_images):
        axs[i].axis('off')
        imshow(images[i],axs[i],class_names[labels[i]])
    plt.show()
# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))
class_names = image_datasets['train'].classes
# Assuming `inputs` is a batch of images and `classes` are the corresponding class labels
plot_batch(inputs, classes, class_names)

# %% [markdown]
# ## **B.** Using a Graphics Card:
#
# Let's start by checking if, for typical architectures like ResNet, using a GPU significantly improves computation time. We will begin by loading the lightest of the ResNet architectures and select an appropriate loss function.

# %% [markdown]
# **Exercise**
#
# - Load an untrained ResNet18. How many total weights does it contain? Check [here](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html).  ==> 11689512
#
# - How many neurons does the last layer of the network have?  == 1000
#
# - Modify the last layer of the classifier so that it has as many neurons as there are classes in hymenoptera_data:

# %%
model = models.resnet18(pretrained=False)
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %% [markdown]
# **Note:** Batch normalization operations facilitate learning but won't be detailed here. In summary, they center/reduce each feature map over the batch and then renormalize. The two renormalization parameters (mean and standard deviation) are trainable.

# %%
# Neurons in the last layer
print(model.fc)
# Out:
# Linear(in_features=512, out_features=1000, bias=True)

# %%
# Modification of the last layer of the classifier
def get_model(pretrained):
  model = models.resnet18(pretrained=pretrained)
  model.fc = nn.Linear(model.fc.in_features, 2)
  return model

get_model(False)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# **Exercise:** Is there a softmax layer at the end of the ResNet architecture?
#
# YOUR ANSWER HERE ==> no

# %% [markdown]
# Now, let's define the negative log-likelihood as the cost function. To compute the log-likelihood, we could add a LogSoftmax layer to the ResNet. Yet it's easier and more common to use a loss function that includes *LogSoftmax*. In this regard, in PyTorch,  *nn.CrossEntropyLoss* combines both *LogSoftmax* and *NLLLoss*.

# %%
loss_fn =  nn.CrossEntropyLoss()

# %% [markdown]
# Finally, let's define a function that incorporates the training loop.

# %% [markdown]
# **Exercise:**
# - Complete the *train_model* function, which takes a model, a loss function, an optimizer, and a number of epochs as arguments.
# - Train the ResNet over one epoch with mini-batches of 64 images.

# %%
def train_model(model, loss_fn, optimizer, num_epochs=1):
    since = time.time()

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
                # Weights are not updated during the validation phase

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                # 1. zeroing grads
                optimizer.zero_grad()
                # raise NotImplementedError()
                with torch.set_grad_enabled(phase == 'train'):
                    # forward step (outputs = ...)
                    # get the predicted classes (preds = ...)
                    # loss computing (loss = ...)
                    output = model(inputs)
                    _, preds = torch.max(output, 1)
                    loss = loss_fn(output, labels)
                    # raise NotImplementedError()
                    if phase == 'train':
                        # backward step
                        # update wieghts
                        loss.backward()
                        optimizer.step()
                        # raise NotImplementedError()
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {100*epoch_acc:.2f}%')

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')

    return model

# %%
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=64,
                                             shuffle=True, num_workers=2)
              for x in ['train', 'val']}

model = get_model(pretrained=False)
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

# Launch the training over 1 epoch:
model = train_model(model, loss_fn, optimizer)
# YOUR CODE HERE
# raise NotImplementedError()
# Out:
# Epoch 0/0
# ----------
# train Loss: 0.6884 Acc: 53.69%
# val Loss: 0.6898 Acc: 54.25%
# Training complete in 0m 52s

# %% [markdown]
# With more than 10 million parameters, training a ResNet on a CPU is much slower than the networks in Part I. \\
# Let's repeat the same training using the GPU.

# %%
print(f'Runtime device :{device}')

# Load the model to the GPU:
model = model.to(device)
# Out:
# Runtime device :cuda:0

# %% [markdown]
# To load a torch.tensor on GPU, the syntax is the same:

# %%
x = torch.rand(2,1,4,4)
print("On CPU :\n",x)
x = x.to(device)
# Note: You can also use .cuda() without specifying the device name
# but this method is not recommended especially in a multi-gpu environment
print("On GPU :\n",x)

# bring back the x tensor to the CPU RAM:
x = x.to('cpu') # or x.cpu()
print('Back to CPU:\n',x)
# Out:
# On CPU :
#  tensor([[[[0.2714, 0.3064, 0.2501, 0.7526],
#           [0.8416, 0.9465, 0.5430, 0.2106],
#           [0.9268, 0.3998, 0.9794, 0.5275],
#           [0.8700, 0.4588, 0.6898, 0.4276]]],
#
#
#         [[[0.9052, 0.7416, 0.0794, 0.4899],
#           [0.9592, 0.3371, 0.9881, 0.4410],
#           [0.4678, 0.0129, 0.3725, 0.0962],
#           [0.8516, 0.5383, 0.8223, 0.6858]]]])
# On GPU :
#  tensor([[[[0.2714, 0.3064, 0.2501, 0.7526],
#           [0.8416, 0.9465, 0.5430, 0.2106],
#           [0.9268, 0.3998, 0.9794, 0.5275],
#           [0.8700, 0.4588, 0.6898, 0.4276]]],
#
#
#         [[[0.9052, 0.7416, 0.0794, 0.4899],
#           [0.9592, 0.3371, 0.9881, 0.4410],
#           [0.4678, 0.0129, 0.3725, 0.0962],
#           [0.8516, 0.5383, 0.8223, 0.6858]]]], device='cuda:0')
# Back to CPU:
#  tensor([[[[0.2714, 0.3064, 0.2501, 0.7526],
#           [0.8416, 0.9465, 0.5430, 0.2106],
#           [0.9268, 0.3998, 0.9794, 0.5275],
#           [0.8700, 0.4588, 0.6898, 0.4276]]],
#
#
#         [[[0.9052, 0.7416, 0.0794, 0.4899],
#           [0.9592, 0.3371, 0.9881, 0.4410],
#           [0.4678, 0.0129, 0.3725, 0.0962],
#           [0.8516, 0.5383, 0.8223, 0.6858]]]])

# %% [markdown]
# **Exercice :**
# - Complete the fonction *train_model_gpu* to train the model on GPU.
# - Compare the CPU and GPU training times.

# %%
def train_model_gpu(model, loss_fn, optimizer, num_epochs=1):
    # Record the starting time
    since = time.time()
    # Loop through epochs
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Iterate through training and validation phases
        for phase in ['train', 'val']:
            # Set the model to training mode during the training phase, and evaluation mode during validation
            if phase == 'train':
                model.train()
            else:
                model.eval()

            # Initialize counters for loss and correct predictions
            running_loss = 0.0
            running_corrects = 0

            # Iterate through batches in the data loader
            for inputs, labels in dataloaders[phase]:
                # Move inputs and labels to the specified device (GPU)
                inputs = inputs.to(device)
                labels = labels.to(device)
                # raise NotImplementedError()

                # Zero the gradients in the optimizer (same as in train_model())
                optimizer.zero_grad()
                # raise NotImplementedError()
                # Forward pass: compute model outputs and predictions (same as in train_model())
                with torch.set_grad_enabled(phase == 'train'):
                    output = model(inputs)
                    _, preds = torch.max(output, 1)
                    loss = loss_fn(output, labels)
                    # raise NotImplementedError()
                    # Backward pass and optimization step if in the training phase (same as in train_model())
                    if phase == 'train':
                        # backward step
                        # update wieghts
                        loss.backward()
                        optimizer.step()
                    # raise NotImplementedError()
                # Update counters
                running_loss += loss.item() * inputs.size(0)
                acc = torch.sum(preds == labels.data)
                # The 'acc' tensor is distributed across different parts of the GPU
                # Gather the 'acc' tensor on the CPU before accumulation
                # running_corrects += ...
                # YOUR CODE HERE
                acc = acc.to('cpu')
                running_corrects += acc

                # raise NotImplementedError()

            # Calculate average loss and accuracy for the epoch
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            # Print epoch statistics
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {100*epoch_acc:.2f}%')

    # Calculate and print the total training time
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    # Return the trained model
    return model


model = get_model(pretrained=False).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

model = train_model_gpu(model, loss_fn, optimizer, num_epochs=1)
# Out:
# Epoch 0/0
# ----------
# train Loss: 0.7194 Acc: 49.18%
# val Loss: 0.6888 Acc: 57.52%
# Training complete in 0m 10s

# %% [markdown]
# ### **GPU**
# A GPU, or Graphics Processing Unit, is a specialized electronic circuit designed to accelerate the processing of images and videos. Originally developed for rendering graphics in video games, GPUs have evolved into highly parallel processors that excel at performing many simultaneous calculations. Unlike CPUs (Central Processing Unit), the GPUs are optimized for parallel processing tasks.
#
# Key characteristics of GPUs include:
#
# 1. **Parallel Processing:** GPUs consist of a large number of cores, allowing them to handle multiple tasks simultaneously. This makes them well-suited for parallelizable computations.
#
# 2. **Vectorized Processing:** GPUs are designed to efficiently perform operations on vectors and matrices. This is particularly beneficial for tasks such as linear algebra operations, which are common in machine learning and scientific computing.
#
# 3. **High Memory Bandwidth:** GPUs have high-speed memory to quickly access and manipulate large amounts of data, making them suitable for tasks that involve substantial data throughput.
#
# 4. **Floating-Point Performance:** GPUs are optimized for floating-point arithmetic, which is important for applications that require precision in numerical calculations.
#
# 5. **Specialized Compute APIs:** Modern GPUs support specialized compute APIs (Application Programming Interfaces) such as CUDA (Compute Unified Device Architecture) for NVIDIA GPUs or OpenCL (Open Computing Language), which allows developers to offload parallelizable tasks to the GPU.
#
# 6. **General-Purpose GPU Computing:** Beyond graphics rendering, GPUs are now widely used for general-purpose computing, including scientific simulations, machine learning, data analysis, and other computationally intensive tasks.
#
# In the context of machine learning, deep learning frameworks like TensorFlow and PyTorch leverage GPUs to accelerate the training of neural networks. The parallel processing capabilities of GPUs enable the simultaneous computation of numerous mathematical operations, significantly speeding up training times compared to using only a CPU.

# %% [markdown]
# ## **C.**  Improving the Training Procedure:
#
# Before comparing different transfer approaches, let's improve the training procedure a bit. We can add momentum to the gradient descent. The  [increment calculation](https://pytorch.org/docs/master/optim.html#torch.optim.SGD) will depend not only on the current gradient but also on past increment values stored in $d_i$:
#
# \begin{equation}
# d_i^{t+1} = momentum \times d_i^{t} +    \dfrac{\partial \mathcal{L_{batch}^{t+1}}} {\partial{\omega_i}} \\
# w_i^{t+1}  = w_i^{t} - lr \times d_i^{t+1}
# \end{equation}
#
# Here is an example:
#
# `optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)`

# %% [markdown]
# Next, we'll add a *scheduler* that gradually decreases the learning rate *lr*. With the following *scheduler*, every five epochs, *lr* is multiplied by gamma = 0.1. \\
# `scheduler =  torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)`
#
# The *scheduler* needs access to the *lr* in the optimizer, so it is passed as an argument. The scheduler acts on *lr* only at the end of an epoch, and to make this action effective, you need to add this line outside the loader iteration loop:
#
# `scheduler.step()`

# %% [markdown]
# **Exercise**: Integrate these elements into the training function. Check that the learning rate decreases as expected.

# %%
def train_model_gpu_scheduler(model, loss_fn, optimizer,scheduler, num_epochs=1):
    # Record the starting time
    since = time.time()
    # Loop through epochs
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Iterate through training and validation phases
        for phase in ['train', 'val']:
            # Set the model to training mode during the training phase, and evaluation mode during validation
            if phase == 'train':
                model.train()
            else:
                model.eval()

            # Initialize counters for loss and correct predictions
            running_loss = 0.0
            running_corrects = 0

            # Iterate through batches in the data loader
            for inputs, labels in dataloaders[phase]:
                # Move inputs and labels to the specified device (same as in train_model_gpu())
                inputs = inputs.to(device)
                labels = labels.to(device)
                # raise NotImplementedError()

                # Zero the gradients in the optimizer (same as in train_model())
                optimizer.zero_grad()
                # raise NotImplementedError()
                # Forward pass: compute model outputs and predictions (same as in train_model())
                with torch.set_grad_enabled(phase == 'train'):
                  outputs = model(inputs)
                  _, preds = torch.max(outputs, 1)
                  loss = loss_fn(outputs, labels)
                    # raise NotImplementedError()
                    # Backward pass and optimization step if in the training phase (same as in train_model())
                  if phase == 'train':
                    loss.backward()
                    optimizer.step()
                    # raise NotImplementedError()

                # Update counters
                running_loss += loss.item() * inputs.size(0)
                acc = torch.sum(preds == labels.data)
                # The 'acc' tensor is distributed across different parts of the GPU
                # Gather the 'acc' tensor on the CPU before accumulation (same as in train_model_gpu())
                acc = acc.to(device)
                running_corrects += acc
                # raise NotImplementedError()

            # Calculate average loss and accuracy for the epoch
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            # Print epoch statistics
            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {100*epoch_acc:.2f}%')
        # update the learning rate
        # print it (hint: look at optimizer.param_groups)
        print("old lr in Epoch {}, Learning Rate: {}".format(epoch, optimizer.param_groups[0]['lr']))
        scheduler.step()

        # Print the updated learning rate after each epoch
        print("new lr in Epoch {}, Learning Rate: {}".format(epoch, optimizer.param_groups[0]['lr']))
        # raise NotImplementedError()

    # Calculate and print the total training time
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    return model

# %%
model = get_model(pretrained=False).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
scheduler =  torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.1)

model = train_model_gpu_scheduler(model, loss_fn, optimizer, scheduler, num_epochs=10)
# Out:
# Epoch 0/9
# ----------
# train Loss: 0.7348 Acc: 51.23%
# val Loss: 0.6877 Acc: 59.48%
# old lr in Epoch 0, Learning Rate: 0.001
# new lr in Epoch 0, Learning Rate: 0.001
# Epoch 1/9
# ----------
# train Loss: 0.7196 Acc: 50.82%
# val Loss: 0.6816 Acc: 56.21%
# old lr in Epoch 1, Learning Rate: 0.001
# new lr in Epoch 1, Learning Rate: 0.0001
# Epoch 2/9
# ----------
# train Loss: 0.7107 Acc: 51.64%
# val Loss: 0.6781 Acc: 57.52%
# old lr in Epoch 2, Learning Rate: 0.0001
# new lr in Epoch 2, Learning Rate: 0.0001
# Epoch 3/9
# ----------
# train Loss: 0.6923 Acc: 55.74%
# val Loss: 0.6781 Acc: 62.09%
# old lr in Epoch 3, Learning Rate: 0.0001
# new lr in Epoch 3, Learning Rate: 1e-05
# Epoch 4/9
# ----------
# train Loss: 0.6777 Acc: 56.97%
# val Loss: 0.6754 Acc: 61.44%
# old lr in Epoch 4, Learning Rate: 1e-05
# new lr in Epoch 4, Learning Rate: 1e-05
# Epoch 5/9
# ----------
# train Loss: 0.6760 Acc: 59.84%
# val Loss: 0.6712 Acc: 64.05%
# old lr in Epoch 5, Learning Rate: 1e-05
# new lr in Epoch 5, Learning Rate: 1.0000000000000002e-06
# Epoch 6/9
# ----------
# train Loss: 0.6715 Acc: 57.79%
# val Loss: 0.6692 Acc: 66.67%
# old lr in Epoch 6, Learning Rate: 1.0000000000000002e-06
# new lr in Epoch 6, Learning Rate: 1.0000000000000002e-06
# Epoch 7/9
# ----------
# train Loss: 0.6778 Acc: 60.25%
# val Loss: 0.6719 Acc: 62.75%
# old lr in Epoch 7, Learning Rate: 1.0000000000000002e-06
# new lr in Epoch 7, Learning Rate: 1.0000000000000002e-07
# Epoch 8/9
# ----------
# train Loss: 0.6709 Acc: 59.02%
# val Loss: 0.6713 Acc: 61.44%
# old lr in Epoch 8, Learning Rate: 1.0000000000000002e-07
# new lr in Epoch 8, Learning Rate: 1.0000000000000002e-07
# Epoch 9/9
# ----------
# train Loss: 0.6764 Acc: 58.20%
# val Loss: 0.6706 Acc: 61.44%
# old lr in Epoch 9, Learning Rate: 1.0000000000000002e-07
# new lr in Epoch 9, Learning Rate: 1.0000000000000004e-08
# Training complete in 0m 29s

# %% [markdown]
# **Important note:** As you may notice, there are quite a few parameters to set, `learning rate`, `momentum`, `gamma`, `step_size`, etc... Typically, we use the parameterization that achieves the best scores on the validation dataset. To do this, we save the weights during training as soon as a validation record is reached. Note that by selecting the model this way, we are essentially training on the validation dataset. \\
# This is why evaluating a selected model on the validation set always takes place on an independent **test dataset**, separate from the validation and training sets.
#
# For reference, here's how to store model weights in PyTorch:
# ```python
# import copy
#
# # At the end of each epoch, save the best model:
# if phase == "val" and epoch_acc > best_val_acc:
#   best_model_wts = copy.deepcopy(model.state_dict())
#
# # After training, before testing the model, load the best model:
# model.load_state_dict(best_model_wts)
# ```

# %% [markdown]
# ## **D.** Impact of pretraining on performance:

# %% [markdown]
# Training is faster on a GPU, but it only leads to a very poor score, barely better than random chance. To improve performance, a simple idea is to use a network trained on a similar (or more general) task as a starting point for learning. Here, it works particularly well with networks trained on ImageNet, whose convolutional filters are already very rich.
#
# **Note:**
# This method is refered to as **fine-tuning** a **pretrained model**.

# %% [markdown]
# **Exercise**:
# Modify the training function to retrieve successive training and validation accuracies.

# %%
import copy

def train(model, loss_fn, optimizer,scheduler, num_epochs=1):
    # Record the starting time
    since = time.time()
    accs = []
    tr_acc = []
    val_acc = []
    best_val_acc = 0
    for epochs in range(num_epochs):
      a=0
      print(f'Epoch {epochs+1}/{num_epochs}')
      print('*'*20)

      for phase in ['train', 'val']:

        ############################################################

        if phase == 'val':
          model.eval()
        else:
          model.train()

        ############################################################

        running_loss = 0.0
        running_corrects = 0.0

        for inputs, labels in dataloaders[phase]:
           inputs = inputs.to(device)
           labels = labels.to(device)
           #########################################################
           optimizer.zero_grad()

           with torch.set_grad_enabled(phase == 'train'):

            outputs = model(inputs)
            _,preds = torch.max(outputs,1)
            loss = loss_fn(outputs, labels)

            ########################################################
            if phase == 'train':
              loss.backward()
              optimizer.step()


           running_loss += loss.item()*inputs.size(0)
           acc = torch.sum(preds == labels.data)
           acc = acc.to(device)
           running_corrects += acc
        ############################################################
        epoch_loss = running_loss / dataset_sizes[phase]
        epoch_acc = running_corrects.double() / dataset_sizes[phase]

        if phase == 'train':
          tr_acc.append(epoch_acc)
        else:
          val_acc.append(epoch_acc)


        print(f'{phase} Loss: {epoch_loss:.4f} Acc: {100*epoch_acc:.2f}%')

        # At the end of each epoch, save the best model:
        if phase == "val" and epoch_acc > best_val_acc:
          best_model_wts = copy.deepcopy(model.state_dict())
          best_val_acc = epoch_acc

        # After training, before testing the model, load the best model:


      print("old lr in Epoch {}, Learning Rate: {}".format(epochs, optimizer.param_groups[0]['lr']))
      scheduler.step()
      # Print the updated learning rate after each epoch
      print("new lr in Epoch {}, Learning Rate: {}".format(epochs, optimizer.param_groups[0]['lr']))
    model.load_state_dict(best_model_wts)
    # Calculate and print the total training time
    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    accs.append(tr_acc)
    accs.append(val_acc)
    return model, accs

# %% [markdown]
# **Exercise:** Compare two ResNet18 trainings, one randomly initialized and the other pre-trained, using learning curves, over 25 epochs.

# %%
max_epochs = 25
# Learning "from scratch" (random weights) :
# get the model
resnet_scratch = models.resnet18(pretrained = False)
resnet_scratch.fc = nn.Linear(512,2)
# Put the model on GPU
resnet_scratch = resnet_scratch .to(device)
optimizer_scratch = torch.optim.SGD(resnet_scratch.parameters(), lr=0.01, momentum=0.9)  # Optimizer
scheduler_scratch = torch.optim.lr_scheduler.StepLR(optimizer_scratch, step_size=10, gamma=0.1)  # Scheduler
resnet_scratch, accs_scratch = train(resnet_scratch, loss_fn, optimizer_scratch, scheduler_scratch, num_epochs=25)


# get the loss, optimize, the scheduler and starting the training
# ...
# resnet_scratch, accs_scratch = train(...)
# YOUR CODE HERE
# raise NotImplementedError()
# Out:
# Epoch 1/25
# ********************
# train Loss: 0.6899 Acc: 52.87%
# val Loss: 0.6528 Acc: 67.32%
# old lr in Epoch 0, Learning Rate: 0.01
# new lr in Epoch 0, Learning Rate: 0.01
# Epoch 2/25
# ********************
# train Loss: 0.6612 Acc: 63.93%
# val Loss: 0.6141 Acc: 69.28%
# old lr in Epoch 1, Learning Rate: 0.01
# new lr in Epoch 1, Learning Rate: 0.01
# Epoch 3/25
# ********************
# train Loss: 0.6149 Acc: 66.39%
# val Loss: 0.5981 Acc: 70.59%
# old lr in Epoch 2, Learning Rate: 0.01
# new lr in Epoch 2, Learning Rate: 0.01
# Epoch 4/25
# ********************
# train Loss: 0.5978 Acc: 63.52%
# val Loss: 0.6964 Acc: 59.48%
# old lr in Epoch 3, Learning Rate: 0.01
# new lr in Epoch 3, Learning Rate: 0.01
# Epoch 5/25
# ********************
# train Loss: 0.6342 Acc: 65.57%
# val Loss: 0.9149 Acc: 62.09%
# old lr in Epoch 4, Learning Rate: 0.01
# new lr in Epoch 4, Learning Rate: 0.01
# Epoch 6/25
# ********************
# train Loss: 0.5942 Acc: 68.44%
# val Loss: 0.6872 Acc: 64.71%
# old lr in Epoch 5, Learning Rate: 0.01
# new lr in Epoch 5, Learning Rate: 0.01
# Epoch 7/25
# ********************
# train Loss: 0.5585 Acc: 71.72%
# val Loss: 1.3241 Acc: 56.86%
# old lr in Epoch 6, Learning Rate: 0.01
# new lr in Epoch 6, Learning Rate: 0.01
# Epoch 8/25
# ********************
# train Loss: 0.5898 Acc: 72.13%
# val Loss: 1.0278 Acc: 62.75%
# old lr in Epoch 7, Learning Rate: 0.01
# new lr in Epoch 7, Learning Rate: 0.01
# Epoch 9/25
# ********************
# train Loss: 0.5130 Acc: 73.36%
# val Loss: 0.8509 Acc: 67.32%
# old lr in Epoch 8, Learning Rate: 0.01
# new lr in Epoch 8, Learning Rate: 0.01
# Epoch 10/25
# ********************
# train Loss: 0.5743 Acc: 68.85%
# val Loss: 0.8761 Acc: 58.17%
# old lr in Epoch 9, Learning Rate: 0.01
# new lr in Epoch 9, Learning Rate: 0.001
# Epoch 11/25
# ********************
# train Loss: 0.5159 Acc: 75.00%
# val Loss: 0.6939 Acc: 68.63%
# old lr in Epoch 10, Learning Rate: 0.001
# new lr in Epoch 10, Learning Rate: 0.001
# Epoch 12/25
# ********************
# train Loss: 0.4545 Acc: 78.69%
# val Loss: 0.6917 Acc: 67.32%
# old lr in Epoch 11, Learning Rate: 0.001
# new lr in Epoch 11, Learning Rate: 0.001
# Epoch 13/25
# ********************
# train Loss: 0.4450 Acc: 77.46%
# val Loss: 0.7222 Acc: 66.67%
# old lr in Epoch 12, Learning Rate: 0.001
# new lr in Epoch 12, Learning Rate: 0.001
# Epoch 14/25
# ********************
# train Loss: 0.4438 Acc: 77.46%
# val Loss: 0.6110 Acc: 73.20%
# old lr in Epoch 13, Learning Rate: 0.001
# new lr in Epoch 13, Learning Rate: 0.001
# Epoch 15/25
# ********************
# train Loss: 0.4564 Acc: 78.28%
# val Loss: 0.5736 Acc: 74.51%
# old lr in Epoch 14, Learning Rate: 0.001
# new lr in Epoch 14, Learning Rate: 0.001
# Epoch 16/25
# ********************
# train Loss: 0.4143 Acc: 81.15%
# val Loss: 0.5847 Acc: 71.24%
# old lr in Epoch 15, Learning Rate: 0.001
# new lr in Epoch 15, Learning Rate: 0.001
# Epoch 17/25
# ********************
# train Loss: 0.4255 Acc: 81.15%
# val Loss: 0.5993 Acc: 70.59%
# old lr in Epoch 16, Learning Rate: 0.001
# new lr in Epoch 16, Learning Rate: 0.001
# Epoch 18/25
# ********************
# train Loss: 0.4193 Acc: 77.46%
# val Loss: 0.6149 Acc: 69.28%
# old lr in Epoch 17, Learning Rate: 0.001
# new lr in Epoch 17, Learning Rate: 0.001
# Epoch 19/25
# ********************
# train Loss: 0.3963 Acc: 80.74%
# val Loss: 0.6090 Acc: 69.28%
# old lr in Epoch 18, Learning Rate: 0.001
# new lr in Epoch 18, Learning Rate: 0.001
# Epoch 20/25
# ********************
# train Loss: 0.3966 Acc: 80.33%
# val Loss: 0.5897 Acc: 71.90%
# old lr in Epoch 19, Learning Rate: 0.001
# new lr in Epoch 19, Learning Rate: 0.0001
# Epoch 21/25
# ********************
# train Loss: 0.3922 Acc: 81.56%
# val Loss: 0.5878 Acc: 70.59%
# old lr in Epoch 20, Learning Rate: 0.0001
# new lr in Epoch 20, Learning Rate: 0.0001
# Epoch 22/25
# ********************
# train Loss: 0.3763 Acc: 84.02%
# val Loss: 0.5875 Acc: 71.90%
# old lr in Epoch 21, Learning Rate: 0.0001
# new lr in Epoch 21, Learning Rate: 0.0001
# Epoch 23/25
# ********************
# train Loss: 0.3807 Acc: 81.97%
# val Loss: 0.5875 Acc: 73.20%
# old lr in Epoch 22, Learning Rate: 0.0001
# new lr in Epoch 22, Learning Rate: 0.0001
# Epoch 24/25
# ********************
# train Loss: 0.3926 Acc: 81.56%
# val Loss: 0.5889 Acc: 71.90%
# old lr in Epoch 23, Learning Rate: 0.0001
# new lr in Epoch 23, Learning Rate: 0.0001
# Epoch 25/25
# ********************
# train Loss: 0.4086 Acc: 78.69%
# val Loss: 0.5891 Acc: 72.55%
# old lr in Epoch 24, Learning Rate: 0.0001
# new lr in Epoch 24, Learning Rate: 0.0001
# Training complete in 1m 32s

# %%
train_accs = accs_scratch[0]
val_accs = accs_scratch[1]

listofmetrics = [train_accs, val_accs]
names = ['train_accs_scratch', 'val_accs_scratch']
listofmetrics_cpu_scratch = [torch.tensor(sub).cpu().numpy() for sub in listofmetrics]
metrics_fig = plt.figure()

for i in range(2):
  plt.subplot(1,2,i+1)
  plt.tight_layout()
  plt.plot(listofmetrics_cpu_scratch[i]) #, interpolation='none')
  plt.title(names[i])
  #plt.xticks([])
  #plt.yticks([])

# %%
# fine tuning a pretrained model:
resnet_ft = models.resnet18(pretrained=True)  # Pretrained ResNet18 model
resnet_ft.fc = nn.Linear(512, 2)  # Output layer for CIFAR-10 dataset
resnet_ft = resnet_ft.to(device)  # Put the model on GPU if available

optimizer_ft = torch.optim.SGD(resnet_ft.parameters(), lr=0.001, momentum=0.9)  # Optimizer for fine-tuning
scheduler_ft = torch.optim.lr_scheduler.StepLR(optimizer_ft, step_size=10, gamma=0.1)  # Scheduler for fine-tuning

resnet_ft, accs_ft = train(resnet_ft, loss_fn, optimizer_ft, scheduler_ft, num_epochs=25)
# raise NotImplementedError()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 126MB/s]
# Epoch 1/25
# ********************
# train Loss: 0.7204 Acc: 54.92%
# val Loss: 0.7503 Acc: 50.33%
# old lr in Epoch 0, Learning Rate: 0.001
# new lr in Epoch 0, Learning Rate: 0.001
# Epoch 2/25
# ********************
# train Loss: 0.6311 Acc: 63.11%
# val Loss: 0.5722 Acc: 71.90%
# old lr in Epoch 1, Learning Rate: 0.001
# new lr in Epoch 1, Learning Rate: 0.001
# Epoch 3/25
# ********************
# train Loss: 0.5033 Acc: 82.38%
# val Loss: 0.4239 Acc: 85.62%
# old lr in Epoch 2, Learning Rate: 0.001
# new lr in Epoch 2, Learning Rate: 0.001
# Epoch 4/25
# ********************
# train Loss: 0.3684 Acc: 87.30%
# val Loss: 0.3363 Acc: 89.54%
# old lr in Epoch 3, Learning Rate: 0.001
# new lr in Epoch 3, Learning Rate: 0.001
# Epoch 5/25
# ********************
# train Loss: 0.3010 Acc: 89.75%
# val Loss: 0.2821 Acc: 92.16%
# old lr in Epoch 4, Learning Rate: 0.001
# new lr in Epoch 4, Learning Rate: 0.001
# Epoch 6/25
# ********************
# train Loss: 0.2570 Acc: 89.75%
# val Loss: 0.2501 Acc: 92.16%
# old lr in Epoch 5, Learning Rate: 0.001
# new lr in Epoch 5, Learning Rate: 0.001
# Epoch 7/25
# ********************
# train Loss: 0.2196 Acc: 93.03%
# val Loss: 0.2279 Acc: 92.81%
# old lr in Epoch 6, Learning Rate: 0.001
# new lr in Epoch 6, Learning Rate: 0.001
# Epoch 8/25
# ********************
# train Loss: 0.2185 Acc: 88.93%
# val Loss: 0.2157 Acc: 93.46%
# old lr in Epoch 7, Learning Rate: 0.001
# new lr in Epoch 7, Learning Rate: 0.001
# Epoch 9/25
# ********************
# train Loss: 0.1850 Acc: 93.03%
# val Loss: 0.2052 Acc: 93.46%
# old lr in Epoch 8, Learning Rate: 0.001
# new lr in Epoch 8, Learning Rate: 0.001
# Epoch 10/25
# ********************
# train Loss: 0.1737 Acc: 94.67%
# val Loss: 0.1970 Acc: 93.46%
# old lr in Epoch 9, Learning Rate: 0.001
# new lr in Epoch 9, Learning Rate: 0.0001
# Epoch 11/25
# ********************
# train Loss: 0.2020 Acc: 92.62%
# val Loss: 0.1975 Acc: 93.46%
# old lr in Epoch 10, Learning Rate: 0.0001
# new lr in Epoch 10, Learning Rate: 0.0001
# Epoch 12/25
# ********************
# train Loss: 0.1545 Acc: 95.08%
# val Loss: 0.1977 Acc: 93.46%
# old lr in Epoch 11, Learning Rate: 0.0001
# new lr in Epoch 11, Learning Rate: 0.0001
# Epoch 13/25
# ********************
# train Loss: 0.1758 Acc: 93.85%
# val Loss: 0.1978 Acc: 93.46%
# old lr in Epoch 12, Learning Rate: 0.0001
# new lr in Epoch 12, Learning Rate: 0.0001
# Epoch 14/25
# ********************
# train Loss: 0.1538 Acc: 95.49%
# val Loss: 0.1973 Acc: 93.46%
# old lr in Epoch 13, Learning Rate: 0.0001
# new lr in Epoch 13, Learning Rate: 0.0001
# Epoch 15/25
# ********************
# train Loss: 0.1610 Acc: 94.67%
# val Loss: 0.1970 Acc: 93.46%
# old lr in Epoch 14, Learning Rate: 0.0001
# new lr in Epoch 14, Learning Rate: 0.0001
# Epoch 16/25
# ********************
# train Loss: 0.1562 Acc: 95.90%
# val Loss: 0.1961 Acc: 92.81%
# old lr in Epoch 15, Learning Rate: 0.0001
# new lr in Epoch 15, Learning Rate: 0.0001
# Epoch 17/25
# ********************
# train Loss: 0.1579 Acc: 94.67%
# val Loss: 0.1950 Acc: 93.46%
# old lr in Epoch 16, Learning Rate: 0.0001
# new lr in Epoch 16, Learning Rate: 0.0001
# Epoch 18/25
# ********************
# train Loss: 0.1660 Acc: 94.67%
# val Loss: 0.1949 Acc: 92.81%
# old lr in Epoch 17, Learning Rate: 0.0001
# new lr in Epoch 17, Learning Rate: 0.0001
# Epoch 19/25
# ********************
# train Loss: 0.1667 Acc: 93.03%
# val Loss: 0.1949 Acc: 92.81%
# old lr in Epoch 18, Learning Rate: 0.0001
# new lr in Epoch 18, Learning Rate: 0.0001
# Epoch 20/25
# ********************
# train Loss: 0.1503 Acc: 94.26%
# val Loss: 0.1950 Acc: 92.81%
# old lr in Epoch 19, Learning Rate: 0.0001
# new lr in Epoch 19, Learning Rate: 1e-05
# Epoch 21/25
# ********************
# train Loss: 0.1474 Acc: 96.72%
# val Loss: 0.1955 Acc: 92.16%
# old lr in Epoch 20, Learning Rate: 1e-05
# new lr in Epoch 20, Learning Rate: 1e-05
# Epoch 22/25
# ********************
# train Loss: 0.1414 Acc: 96.31%
# val Loss: 0.1964 Acc: 92.16%
# old lr in Epoch 21, Learning Rate: 1e-05
# new lr in Epoch 21, Learning Rate: 1e-05
# Epoch 23/25
# ********************
# train Loss: 0.1514 Acc: 95.90%
# val Loss: 0.1961 Acc: 92.81%
# old lr in Epoch 22, Learning Rate: 1e-05
# new lr in Epoch 22, Learning Rate: 1e-05
# Epoch 24/25
# ********************
# train Loss: 0.1997 Acc: 93.03%
# val Loss: 0.1954 Acc: 92.16%
# old lr in Epoch 23, Learning Rate: 1e-05
# new lr in Epoch 23, Learning Rate: 1e-05
# Epoch 25/25
# ********************
# train Loss: 0.1598 Acc: 94.67%
# val Loss: 0.1954 Acc: 92.16%
# old lr in Epoch 24, Learning Rate: 1e-05
# new lr in Epoch 24, Learning Rate: 1e-05
# Training complete in 1m 21s

# %%
train_accs = accs_ft[0]
val_accs = accs_ft[1]

listofmetrics = [train_accs, val_accs]
names = ['train_accs_ft', 'val_accs_ft']
listofmetrics_cpu_ft = [torch.tensor(sub).cpu().numpy() for sub in listofmetrics]
metrics_fig = plt.figure()

for i in range(2):
  plt.subplot(1,2,i+1)
  plt.tight_layout()
  plt.plot(listofmetrics_cpu_ft[i]) #, interpolation='none')
  plt.title(names[i])
  #plt.xticks([])
  #plt.yticks([])

# %% [markdown]
# **Learning curves**

# %%
# Set the style
plt.style.use('seaborn-whitegrid')
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))
# Plot the data with improved style
epochs = np.arange(max_epochs)
accs_scratch_dic  = {'train': listofmetrics_cpu_scratch[0],'val' : listofmetrics_cpu_scratch[1]}
accs_ft_dic  = {'train': listofmetrics_cpu_ft[0],'val' : listofmetrics_cpu_ft[1]}
# YOUR CODE HERE
# raise NotImplementedError()
# Assuming accs_scratch and accs_ft are dictionaries with 'val' as a key
# you can use the following lines
ax.plot(epochs, 100 * np.array(accs_scratch_dic['val']), color='skyblue',
       label='Training from Scratch', marker='o', linestyle='-', linewidth=2)
ax.plot(epochs, 100 * np.array(accs_ft_dic['val']), color='lightgreen',
       label='Fine Tuning', marker='s', linestyle='-', linewidth=2)

# Set title and axis labels
ax.set_title('Validation Accuracy Over Epochs', fontsize=16)
ax.set_ylabel("Accuracy (%)", fontsize=14)
ax.set_xlabel("Epochs", fontsize=14)

# Set grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)
# Add legend with a border and shadow
ax.legend(frameon=True, fancybox=True, shadow=True, framealpha=0.9, fontsize=12)
plt.show()
# Out:
# <ipython-input-29-8494cf7c7f0f>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# The fine-tuning approach has many variations that fit into the broader framework of **transfer learning**. Partial fine-tuning, as illustrated in the following exercise, is one of these variations.

# %% [markdown]
# **Exercise:** Instead of retraining all the weights, you can simply use the weights of the classifier. This is referred to as *freezing* the other weights during retraining.
# - Implement this approach and compare it with the previous ones.

# %%
resnet = torchvision.models.resnet18(pretrained=True)

num_ftrs = resnet.fc.in_features
resnet.fc = nn.Linear(num_ftrs, 2)

# freeze all the layers except the classifier (the last dense layers at end)
# YOUR CODE HERE


for parameter in resnet.parameters():
  parameter.requires_grad = False

for parameter in resnet.fc.parameters():
  parameter.requires_grad = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
freezed_resnet = resnet.to(device)
# train the model
# ...
freezed_resnet, accs_freezing = train(resnet, loss_fn, optimizer, scheduler, 10)
# YOUR CODE HERE
# raise NotImplementedError()
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/10
# ********************
# train Loss: 0.8203 Acc: 43.03%
# val Loss: 0.7646 Acc: 48.37%
# old lr in Epoch 0, Learning Rate: 1.0000000000000029e-55
# new lr in Epoch 0, Learning Rate: 1.000000000000003e-56
# Epoch 2/10
# ********************
# train Loss: 0.8016 Acc: 45.08%
# val Loss: 0.7597 Acc: 49.67%
# old lr in Epoch 1, Learning Rate: 1.000000000000003e-56
# new lr in Epoch 1, Learning Rate: 1.000000000000003e-56
# Epoch 3/10
# ********************
# train Loss: 0.7914 Acc: 45.08%
# val Loss: 0.7611 Acc: 49.67%
# old lr in Epoch 2, Learning Rate: 1.000000000000003e-56
# new lr in Epoch 2, Learning Rate: 1.000000000000003e-57
# Epoch 4/10
# ********************
# train Loss: 0.8048 Acc: 43.44%
# val Loss: 0.7602 Acc: 50.98%
# old lr in Epoch 3, Learning Rate: 1.000000000000003e-57
# new lr in Epoch 3, Learning Rate: 1.000000000000003e-57
# Epoch 5/10
# ********************
# train Loss: 0.7881 Acc: 43.85%
# val Loss: 0.7606 Acc: 50.98%
# old lr in Epoch 4, Learning Rate: 1.000000000000003e-57
# new lr in Epoch 4, Learning Rate: 1.0000000000000032e-58
# Epoch 6/10
# ********************
# train Loss: 0.8183 Acc: 41.80%
# val Loss: 0.7593 Acc: 50.98%
# old lr in Epoch 5, Learning Rate: 1.0000000000000032e-58
# new lr in Epoch 5, Learning Rate: 1.0000000000000032e-58
# Epoch 7/10
# ********************
# train Loss: 0.8101 Acc: 44.26%
# val Loss: 0.7571 Acc: 50.98%
# old lr in Epoch 6, Learning Rate: 1.0000000000000032e-58
# new lr in Epoch 6, Learning Rate: 1.0000000000000033e-59
# Epoch 8/10
# ********************
# train Loss: 0.8043 Acc: 47.13%
# val Loss: 0.7586 Acc: 51.63%
# old lr in Epoch 7, Learning Rate: 1.0000000000000033e-59
# new lr in Epoch 7, Learning Rate: 1.0000000000000033e-59
# Epoch 9/10
# ********************
# train Loss: 0.8422 Acc: 39.34%
# val Loss: 0.7584 Acc: 51.63%
# old lr in Epoch 8, Learning Rate: 1.0000000000000033e-59
# new lr in Epoch 8, Learning Rate: 1.0000000000000034e-60
# Epoch 10/10
# ********************
# train Loss: 0.8008 Acc: 43.85%
# val Loss: 0.7592 Acc: 50.98%
# old lr in Epoch 9, Learning Rate: 1.0000000000000034e-60
# new lr in Epoch 9, Learning Rate: 1.0000000000000034e-60
# Training complete in 0m 28s

# %%
# Set the style
plt.style.use('seaborn-whitegrid')
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))
# Plot the data with improved style
epochs = np.arange(10)
freezed_resnet, accs_freezing
# YOUR CODE HERE
# raise NotImplementedError()
#######################################

listofmetrics_freeze = [torch.tensor(sub).cpu().numpy() for sub in accs_freezing]
accs_freeze_dic  = {'train': listofmetrics_freeze[0],'val' : listofmetrics_freeze[1]}
# Assuming accs_scratch and accs_ft are dictionaries with 'val' as a key
# you can use the following lines
ax.plot(epochs, 100 * np.array(accs_freeze_dic['val']), color='skyblue', label='Training from Scratch', marker='o', linestyle='-', linewidth=2)
#ax.plot(epochs, 100 * np.array(accs_freeze_dic['train']), color='lightgreen', label='Fine Tuning', marker='s', linestyle='-', linewidth=2)
######################################
# Set title and axis labels
ax.set_title('Validation Accuracy Over Epochs', fontsize=16)
ax.set_ylabel("Accuracy (%)", fontsize=14)
ax.set_xlabel("Epochs", fontsize=14)

# Set grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)
# Add legend with a border and shadow
ax.legend(frameon=True, fancybox=True, shadow=True, framealpha=0.9, fontsize=12)
plt.show()
# Out:
# <ipython-input-52-320035ca5773>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# In the end, for this small dataset, retraining the last layer performs just as well as global training. To conclude, let's make some predictions with the model on the validation dataset:

# %%
def visualize_model(model, num_images=50):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure(figsize=(25,num_images//5*5))

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//5, 5, images_so_far)
                ax.axis('off')
                imshow(inputs.cpu().data[j],ax,'Predicted: {}'.format(class_names[preds[j]]))

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
visualize_model(freezed_resnet)
